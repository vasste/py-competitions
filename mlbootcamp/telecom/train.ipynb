# %%
import numpy as np
import pandas as pd
import math
import os
os.chdir('/home/vasste/ml')
from telecom.train_columns import *
os.chdir('/home/vasste/mlbootcap/TelecomDataCup/dataset')
x = pd.read_pickle('x.pk')
y = pd.read_pickle('y.pk')
x = x.join(y)
# for i in range(10):
#     x['dv' + str(i)] = x['SUM_MINUTES_' + str(i)]/x['VOICE_DUR_MIN_' + str(i)]
# x = x.replace([np.inf, -np.inf], np.nan)
# x = x.fillna(0, axis=0)
col = ['CSI']
xc = x.corr()
xc[col][(xc[col]>.04)].style.background_gradient()
# Out:
# /home/vasste/.conda/envs/ml-boot-cap/lib/python3.6/site-packages/matplotlib/colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_5214bc18_0142_11e9_a16c_791b6d8f8211row0_col0 {
#             background-color:  #fff7fb;
#         }    #T_5214bc18_0142_11e9_a16c_791b6d8f8211row1_col0 {
#             background-color:  #fff7fb;
#         }    #T_5214bc18_0142_11e9_a16c_791b6d8f8211row2_col0 {
#             background-color:  #fff7fb;
#         }    #T_5214bc18_0142_11e9_a16c_791b6d8f8211row3_col0 {
#             background-color:  #fff7fb;
#         }    #T_5214bc18_0142_11e9_a16c_791b6d8f8211row4_col0 {
#             background-color:  #fff7fb;
#         }    #T_5214bc18_0142_11e9_a16c_791b6d8f8211row5_col0 {
#             background-color:  #fff7fb;
#         }    #T_5214bc18_0142_11e9_a16c_791b6d8f8211row6_col0 {
#             background-color:  #fff7fb;
# ...
